# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 246.8720 - y1_output_loss: 118.4436 - y2_output_loss: 126.1478 - y1_output_root_mean_squared_error: 10.9327 - y2_output_root_mean_squared_error: 11.2849 - val_loss: 45.1448 - val_y1_output_loss: 17.2872 - val_y2_output_loss: 28.0721 - val_y1_output_root_mean_squared_error: 4.1785 - val_y2_output_root_mean_squared_error: 5.2616
# Epoch 2/500
# 614/614 [==============================] - 0s 165us/sample - loss: 31.0601 - y1_output_loss: 13.2117 - y2_output_loss: 18.8046 - y1_output_root_mean_squared_error: 3.5877 - y2_output_root_mean_squared_error: 4.2648 - val_loss: 160.7771 - val_y1_output_loss: 28.9490 - val_y2_output_loss: 131.3824 - val_y1_output_root_mean_squared_error: 5.4439 - val_y2_output_root_mean_squared_error: 11.4517
# Epoch 3/500
# 614/614 [==============================] - 0s 167us/sample - loss: 29.0348 - y1_output_loss: 10.7722 - y2_output_loss: 18.1131 - y1_output_root_mean_squared_error: 3.2930 - y2_output_root_mean_squared_error: 4.2651 - val_loss: 19.7147 - val_y1_output_loss: 8.8871 - val_y2_output_loss: 10.6727 - val_y1_output_root_mean_squared_error: 2.9839 - val_y2_output_root_mean_squared_error: 3.2880
# Epoch 4/500
# 614/614 [==============================] - 0s 158us/sample - loss: 24.9515 - y1_output_loss: 9.8503 - y2_output_loss: 15.1148 - y1_output_root_mean_squared_error: 3.1252 - y2_output_root_mean_squared_error: 3.8968 - val_loss: 31.7105 - val_y1_output_loss: 11.0396 - val_y2_output_loss: 20.7161 - val_y1_output_root_mean_squared_error: 3.2879 - val_y2_output_root_mean_squared_error: 4.5717
# Epoch 5/500
# 614/614 [==============================] - 0s 152us/sample - loss: 29.0354 - y1_output_loss: 10.3064 - y2_output_loss: 18.5668 - y1_output_root_mean_squared_error: 3.2170 - y2_output_root_mean_squared_error: 4.3228 - val_loss: 23.0131 - val_y1_output_loss: 10.5708 - val_y2_output_loss: 12.5983 - val_y1_output_root_mean_squared_error: 3.2255 - val_y2_output_root_mean_squared_error: 3.5510
# Epoch 6/500
# 614/614 [==============================] - 0s 159us/sample - loss: 23.4569 - y1_output_loss: 8.9287 - y2_output_loss: 14.6296 - y1_output_root_mean_squared_error: 2.9848 - y2_output_root_mean_squared_error: 3.8142 - val_loss: 47.8379 - val_y1_output_loss: 12.7153 - val_y2_output_loss: 35.6019 - val_y1_output_root_mean_squared_error: 3.5015 - val_y2_output_root_mean_squared_error: 5.9647
# Epoch 7/500
# 614/614 [==============================] - 0s 165us/sample - loss: 30.2133 - y1_output_loss: 9.7100 - y2_output_loss: 20.2671 - y1_output_root_mean_squared_error: 3.1273 - y2_output_root_mean_squared_error: 4.5203 - val_loss: 21.0081 - val_y1_output_loss: 7.9483 - val_y2_output_loss: 13.0789 - val_y1_output_root_mean_squared_error: 2.8129 - val_y2_output_root_mean_squared_error: 3.6188
# Epoch 8/500
# 614/614 [==============================] - 0s 159us/sample - loss: 23.3671 - y1_output_loss: 9.2217 - y2_output_loss: 14.4226 - y1_output_root_mean_squared_error: 3.0245 - y2_output_root_mean_squared_error: 3.7709 - val_loss: 34.1090 - val_y1_output_loss: 9.8867 - val_y2_output_loss: 24.5652 - val_y1_output_root_mean_squared_error: 3.0872 - val_y2_output_root_mean_squared_error: 4.9576
# Epoch 9/500
# 614/614 [==============================] - 0s 167us/sample - loss: 24.3617 - y1_output_loss: 8.8717 - y2_output_loss: 15.2618 - y1_output_root_mean_squared_error: 2.9925 - y2_output_root_mean_squared_error: 3.9251 - val_loss: 18.6539 - val_y1_output_loss: 8.2302 - val_y2_output_loss: 10.5798 - val_y1_output_root_mean_squared_error: 2.8440 - val_y2_output_root_mean_squared_error: 3.2505
# Epoch 10/500
# 614/614 [==============================] - 0s 152us/sample - loss: 20.0199 - y1_output_loss: 7.9258 - y2_output_loss: 12.0922 - y1_output_root_mean_squared_error: 2.8181 - y2_output_root_mean_squared_error: 3.4753 - val_loss: 53.1009 - val_y1_output_loss: 19.4023 - val_y2_output_loss: 34.8616 - val_y1_output_root_mean_squared_error: 4.3012 - val_y2_output_root_mean_squared_error: 5.8822
# Epoch 11/500
# 614/614 [==============================] - 0s 150us/sample - loss: 25.2715 - y1_output_loss: 9.1757 - y2_output_loss: 16.1703 - y1_output_root_mean_squared_error: 3.0271 - y2_output_root_mean_squared_error: 4.0135 - val_loss: 19.2340 - val_y1_output_loss: 8.8455 - val_y2_output_loss: 10.3833 - val_y1_output_root_mean_squared_error: 2.9723 - val_y2_output_root_mean_squared_error: 3.2248
# Epoch 12/500
# 614/614 [==============================] - 0s 152us/sample - loss: 21.7913 - y1_output_loss: 7.7982 - y2_output_loss: 14.0591 - y1_output_root_mean_squared_error: 2.7996 - y2_output_root_mean_squared_error: 3.7354 - val_loss: 22.7393 - val_y1_output_loss: 8.1864 - val_y2_output_loss: 14.8438 - val_y1_output_root_mean_squared_error: 2.8187 - val_y2_output_root_mean_squared_error: 3.8463
# Epoch 13/500
# 614/614 [==============================] - 0s 160us/sample - loss: 20.5451 - y1_output_loss: 7.6821 - y2_output_loss: 12.7087 - y1_output_root_mean_squared_error: 2.7817 - y2_output_root_mean_squared_error: 3.5788 - val_loss: 16.9488 - val_y1_output_loss: 7.9955 - val_y2_output_loss: 9.3715 - val_y1_output_root_mean_squared_error: 2.7675 - val_y2_output_root_mean_squared_error: 3.0479
# Epoch 14/500
# 614/614 [==============================] - 0s 157us/sample - loss: 17.0345 - y1_output_loss: 7.0460 - y2_output_loss: 9.8946 - y1_output_root_mean_squared_error: 2.6644 - y2_output_root_mean_squared_error: 3.1521 - val_loss: 15.5690 - val_y1_output_loss: 6.8663 - val_y2_output_loss: 8.8336 - val_y1_output_root_mean_squared_error: 2.5922 - val_y2_output_root_mean_squared_error: 2.9748
# Epoch 15/500
# 614/614 [==============================] - 0s 159us/sample - loss: 19.3314 - y1_output_loss: 7.6887 - y2_output_loss: 11.7239 - y1_output_root_mean_squared_error: 2.7660 - y2_output_root_mean_squared_error: 3.4177 - val_loss: 21.2471 - val_y1_output_loss: 7.7112 - val_y2_output_loss: 13.5890 - val_y1_output_root_mean_squared_error: 2.7790 - val_y2_output_root_mean_squared_error: 3.6775
# Epoch 16/500
# 614/614 [==============================] - 0s 149us/sample - loss: 17.9089 - y1_output_loss: 6.6498 - y2_output_loss: 11.1252 - y1_output_root_mean_squared_error: 2.5884 - y2_output_root_mean_squared_error: 3.3480 - val_loss: 19.7315 - val_y1_output_loss: 8.6215 - val_y2_output_loss: 11.7337 - val_y1_output_root_mean_squared_error: 2.8565 - val_y2_output_root_mean_squared_error: 3.4017
# Epoch 17/500
# 614/614 [==============================] - 0s 148us/sample - loss: 17.9771 - y1_output_loss: 6.7802 - y2_output_loss: 11.3140 - y1_output_root_mean_squared_error: 2.5762 - y2_output_root_mean_squared_error: 3.3676 - val_loss: 13.7749 - val_y1_output_loss: 5.9060 - val_y2_output_loss: 8.2059 - val_y1_output_root_mean_squared_error: 2.3847 - val_y2_output_root_mean_squared_error: 2.8440
# Epoch 18/500
# 614/614 [==============================] - 0s 158us/sample - loss: 18.9351 - y1_output_loss: 6.7940 - y2_output_loss: 12.0501 - y1_output_root_mean_squared_error: 2.6164 - y2_output_root_mean_squared_error: 3.4770 - val_loss: 15.8382 - val_y1_output_loss: 6.5888 - val_y2_output_loss: 9.7829 - val_y1_output_root_mean_squared_error: 2.4914 - val_y2_output_root_mean_squared_error: 3.1034
# Epoch 19/500
# 614/614 [==============================] - 0s 160us/sample - loss: 15.7807 - y1_output_loss: 5.8686 - y2_output_loss: 9.7748 - y1_output_root_mean_squared_error: 2.4331 - y2_output_root_mean_squared_error: 3.1402 - val_loss: 13.6315 - val_y1_output_loss: 6.1916 - val_y2_output_loss: 7.9692 - val_y1_output_root_mean_squared_error: 2.4156 - val_y2_output_root_mean_squared_error: 2.7922
# Epoch 20/500
# 614/614 [==============================] - 0s 165us/sample - loss: 15.0018 - y1_output_loss: 5.8452 - y2_output_loss: 9.8264 - y1_output_root_mean_squared_error: 2.4050 - y2_output_root_mean_squared_error: 3.0360 - val_loss: 87.0694 - val_y1_output_loss: 15.3988 - val_y2_output_loss: 72.4485 - val_y1_output_root_mean_squared_error: 3.8379 - val_y2_output_root_mean_squared_error: 8.5053
# Epoch 21/500
# 614/614 [==============================] - 0s 162us/sample - loss: 18.7957 - y1_output_loss: 6.6560 - y2_output_loss: 12.2458 - y1_output_root_mean_squared_error: 2.5773 - y2_output_root_mean_squared_error: 3.4862 - val_loss: 18.3155 - val_y1_output_loss: 6.2726 - val_y2_output_loss: 12.3616 - val_y1_output_root_mean_squared_error: 2.4770 - val_y2_output_root_mean_squared_error: 3.4900
# Epoch 22/500
# 614/614 [==============================] - 0s 152us/sample - loss: 16.4530 - y1_output_loss: 5.7333 - y2_output_loss: 10.6839 - y1_output_root_mean_squared_error: 2.3895 - y2_output_root_mean_squared_error: 3.2777 - val_loss: 11.3227 - val_y1_output_loss: 5.1097 - val_y2_output_loss: 6.6157 - val_y1_output_root_mean_squared_error: 2.2029 - val_y2_output_root_mean_squared_error: 2.5436
# Epoch 23/500
# 614/614 [==============================] - 0s 153us/sample - loss: 13.4592 - y1_output_loss: 4.9761 - y2_output_loss: 8.3700 - y1_output_root_mean_squared_error: 2.2406 - y2_output_root_mean_squared_error: 2.9049 - val_loss: 12.5430 - val_y1_output_loss: 5.2196 - val_y2_output_loss: 7.7673 - val_y1_output_root_mean_squared_error: 2.2119 - val_y2_output_root_mean_squared_error: 2.7660
# Epoch 24/500
# 614/614 [==============================] - 0s 155us/sample - loss: 18.5540 - y1_output_loss: 6.1461 - y2_output_loss: 12.3962 - y1_output_root_mean_squared_error: 2.4907 - y2_output_root_mean_squared_error: 3.5143 - val_loss: 11.9657 - val_y1_output_loss: 5.7262 - val_y2_output_loss: 6.6615 - val_y1_output_root_mean_squared_error: 2.3287 - val_y2_output_root_mean_squared_error: 2.5579
# Epoch 25/500
# 614/614 [==============================] - 0s 159us/sample - loss: 12.3839 - y1_output_loss: 4.6800 - y2_output_loss: 7.6040 - y1_output_root_mean_squared_error: 2.1730 - y2_output_root_mean_squared_error: 2.7680 - val_loss: 10.4880 - val_y1_output_loss: 4.7835 - val_y2_output_loss: 6.0116 - val_y1_output_root_mean_squared_error: 2.1440 - val_y2_output_root_mean_squared_error: 2.4272
# Epoch 26/500
# 614/614 [==============================] - 0s 168us/sample - loss: 11.1945 - y1_output_loss: 4.1956 - y2_output_loss: 6.9262 - y1_output_root_mean_squared_error: 2.0565 - y2_output_root_mean_squared_error: 2.6392 - val_loss: 23.4284 - val_y1_output_loss: 7.8284 - val_y2_output_loss: 15.7000 - val_y1_output_root_mean_squared_error: 2.8094 - val_y2_output_root_mean_squared_error: 3.9415
# Epoch 27/500
# 614/614 [==============================] - 0s 154us/sample - loss: 14.5284 - y1_output_loss: 4.9572 - y2_output_loss: 9.7948 - y1_output_root_mean_squared_error: 2.2230 - y2_output_root_mean_squared_error: 3.0963 - val_loss: 47.2929 - val_y1_output_loss: 12.4766 - val_y2_output_loss: 35.2806 - val_y1_output_root_mean_squared_error: 3.4566 - val_y2_output_root_mean_squared_error: 5.9451
# Epoch 28/500
# 614/614 [==============================] - 0s 150us/sample - loss: 11.6624 - y1_output_loss: 4.3365 - y2_output_loss: 7.3885 - y1_output_root_mean_squared_error: 2.0863 - y2_output_root_mean_squared_error: 2.7036 - val_loss: 20.9012 - val_y1_output_loss: 5.6911 - val_y2_output_loss: 15.4084 - val_y1_output_root_mean_squared_error: 2.3256 - val_y2_output_root_mean_squared_error: 3.9361
# Epoch 29/500
# 614/614 [==============================] - 0s 155us/sample - loss: 10.5286 - y1_output_loss: 3.7592 - y2_output_loss: 6.6956 - y1_output_root_mean_squared_error: 1.9460 - y2_output_root_mean_squared_error: 2.5965 - val_loss: 9.8746 - val_y1_output_loss: 4.3407 - val_y2_output_loss: 5.9299 - val_y1_output_root_mean_squared_error: 2.0127 - val_y2_output_root_mean_squared_error: 2.4132
# Epoch 30/500
# 614/614 [==============================] - 0s 158us/sample - loss: 11.6292 - y1_output_loss: 4.0765 - y2_output_loss: 7.4638 - y1_output_root_mean_squared_error: 2.0269 - y2_output_root_mean_squared_error: 2.7424 - val_loss: 8.4448 - val_y1_output_loss: 3.7191 - val_y2_output_loss: 5.0226 - val_y1_output_root_mean_squared_error: 1.8779 - val_y2_output_root_mean_squared_error: 2.2177
# Epoch 31/500
# 614/614 [==============================] - 0s 156us/sample - loss: 10.0113 - y1_output_loss: 3.4541 - y2_output_loss: 6.5072 - y1_output_root_mean_squared_error: 1.8659 - y2_output_root_mean_squared_error: 2.5554 - val_loss: 9.8028 - val_y1_output_loss: 3.4680 - val_y2_output_loss: 6.4597 - val_y1_output_root_mean_squared_error: 1.8214 - val_y2_output_root_mean_squared_error: 2.5466
# Epoch 32/500
# 614/614 [==============================] - 0s 167us/sample - loss: 9.5805 - y1_output_loss: 3.2854 - y2_output_loss: 6.2279 - y1_output_root_mean_squared_error: 1.8204 - y2_output_root_mean_squared_error: 2.5033 - val_loss: 8.5749 - val_y1_output_loss: 3.4966 - val_y2_output_loss: 5.1724 - val_y1_output_root_mean_squared_error: 1.8431 - val_y2_output_root_mean_squared_error: 2.2755
# Epoch 33/500
# 614/614 [==============================] - 0s 148us/sample - loss: 9.6583 - y1_output_loss: 3.4267 - y2_output_loss: 6.2140 - y1_output_root_mean_squared_error: 1.8496 - y2_output_root_mean_squared_error: 2.4975 - val_loss: 10.1121 - val_y1_output_loss: 3.7580 - val_y2_output_loss: 6.5473 - val_y1_output_root_mean_squared_error: 1.9269 - val_y2_output_root_mean_squared_error: 2.5296
# Epoch 34/500
# 614/614 [==============================] - 0s 151us/sample - loss: 11.4598 - y1_output_loss: 3.7695 - y2_output_loss: 7.6536 - y1_output_root_mean_squared_error: 1.9374 - y2_output_root_mean_squared_error: 2.7760 - val_loss: 7.9259 - val_y1_output_loss: 3.1800 - val_y2_output_loss: 4.9117 - val_y1_output_root_mean_squared_error: 1.7622 - val_y2_output_root_mean_squared_error: 2.1956
# Epoch 35/500
# 614/614 [==============================] - 0s 162us/sample - loss: 9.5842 - y1_output_loss: 3.3816 - y2_output_loss: 6.2003 - y1_output_root_mean_squared_error: 1.8294 - y2_output_root_mean_squared_error: 2.4975 - val_loss: 7.2646 - val_y1_output_loss: 2.8936 - val_y2_output_loss: 4.7021 - val_y1_output_root_mean_squared_error: 1.6617 - val_y2_output_root_mean_squared_error: 2.1221
# Epoch 36/500
# 614/614 [==============================] - 0s 164us/sample - loss: 10.9561 - y1_output_loss: 3.5886 - y2_output_loss: 7.3206 - y1_output_root_mean_squared_error: 1.8997 - y2_output_root_mean_squared_error: 2.7106 - val_loss: 8.2837 - val_y1_output_loss: 3.5659 - val_y2_output_loss: 5.0609 - val_y1_output_root_mean_squared_error: 1.8191 - val_y2_output_root_mean_squared_error: 2.2304
# Epoch 37/500
# 614/614 [==============================] - 0s 168us/sample - loss: 8.3182 - y1_output_loss: 2.7125 - y2_output_loss: 5.5982 - y1_output_root_mean_squared_error: 1.6502 - y2_output_root_mean_squared_error: 2.3654 - val_loss: 6.9569 - val_y1_output_loss: 3.0603 - val_y2_output_loss: 4.0919 - val_y1_output_root_mean_squared_error: 1.7054 - val_y2_output_root_mean_squared_error: 2.0121
# Epoch 38/500
# 614/614 [==============================] - 0s 153us/sample - loss: 8.8813 - y1_output_loss: 2.9133 - y2_output_loss: 5.9133 - y1_output_root_mean_squared_error: 1.7102 - y2_output_root_mean_squared_error: 2.4406 - val_loss: 6.0885 - val_y1_output_loss: 2.5740 - val_y2_output_loss: 3.7990 - val_y1_output_root_mean_squared_error: 1.5455 - val_y2_output_root_mean_squared_error: 1.9236
# Epoch 39/500
# 614/614 [==============================] - 0s 163us/sample - loss: 9.4509 - y1_output_loss: 3.0609 - y2_output_loss: 6.4019 - y1_output_root_mean_squared_error: 1.7529 - y2_output_root_mean_squared_error: 2.5255 - val_loss: 7.6820 - val_y1_output_loss: 3.0906 - val_y2_output_loss: 4.8197 - val_y1_output_root_mean_squared_error: 1.6956 - val_y2_output_root_mean_squared_error: 2.1925
# Epoch 40/500
# 614/614 [==============================] - 0s 164us/sample - loss: 8.4230 - y1_output_loss: 2.6029 - y2_output_loss: 5.8163 - y1_output_root_mean_squared_error: 1.6185 - y2_output_root_mean_squared_error: 2.4090 - val_loss: 8.4681 - val_y1_output_loss: 2.8117 - val_y2_output_loss: 5.8168 - val_y1_output_root_mean_squared_error: 1.6231 - val_y2_output_root_mean_squared_error: 2.4153
# Epoch 41/500
# 614/614 [==============================] - 0s 161us/sample - loss: 7.9610 - y1_output_loss: 2.5702 - y2_output_loss: 5.3416 - y1_output_root_mean_squared_error: 1.6076 - y2_output_root_mean_squared_error: 2.3187 - val_loss: 6.1258 - val_y1_output_loss: 2.5455 - val_y2_output_loss: 3.7183 - val_y1_output_root_mean_squared_error: 1.5596 - val_y2_output_root_mean_squared_error: 1.9218
# Epoch 42/500
# 614/614 [==============================] - 0s 155us/sample - loss: 8.6270 - y1_output_loss: 2.8599 - y2_output_loss: 5.7994 - y1_output_root_mean_squared_error: 1.6934 - y2_output_root_mean_squared_error: 2.3999 - val_loss: 7.6721 - val_y1_output_loss: 3.0138 - val_y2_output_loss: 4.7565 - val_y1_output_root_mean_squared_error: 1.6914 - val_y2_output_root_mean_squared_error: 2.1934
# Epoch 43/500
# 614/614 [==============================] - 0s 167us/sample - loss: 6.1147 - y1_output_loss: 2.0761 - y2_output_loss: 4.0136 - y1_output_root_mean_squared_error: 1.4429 - y2_output_root_mean_squared_error: 2.0082 - val_loss: 8.8263 - val_y1_output_loss: 3.5554 - val_y2_output_loss: 5.2805 - val_y1_output_root_mean_squared_error: 1.8641 - val_y2_output_root_mean_squared_error: 2.3133
# Epoch 44/500
# 614/614 [==============================] - 0s 153us/sample - loss: 7.6212 - y1_output_loss: 2.6208 - y2_output_loss: 5.0058 - y1_output_root_mean_squared_error: 1.6242 - y2_output_root_mean_squared_error: 2.2323 - val_loss: 15.7465 - val_y1_output_loss: 3.9223 - val_y2_output_loss: 11.8357 - val_y1_output_root_mean_squared_error: 1.9327 - val_y2_output_root_mean_squared_error: 3.4657
# Epoch 45/500
# 614/614 [==============================] - 0s 153us/sample - loss: 7.7075 - y1_output_loss: 2.4187 - y2_output_loss: 5.2265 - y1_output_root_mean_squared_error: 1.5590 - y2_output_root_mean_squared_error: 2.2971 - val_loss: 5.6011 - val_y1_output_loss: 2.1748 - val_y2_output_loss: 3.5090 - val_y1_output_root_mean_squared_error: 1.4526 - val_y2_output_root_mean_squared_error: 1.8684
# Epoch 46/500
# 614/614 [==============================] - 0s 160us/sample - loss: 10.7225 - y1_output_loss: 3.5213 - y2_output_loss: 7.1175 - y1_output_root_mean_squared_error: 1.8841 - y2_output_root_mean_squared_error: 2.6782 - val_loss: 6.7268 - val_y1_output_loss: 2.5669 - val_y2_output_loss: 4.2314 - val_y1_output_root_mean_squared_error: 1.5674 - val_y2_output_root_mean_squared_error: 2.0664
# Epoch 47/500
# 614/614 [==============================] - 0s 167us/sample - loss: 7.1248 - y1_output_loss: 2.4077 - y2_output_loss: 4.7707 - y1_output_root_mean_squared_error: 1.5498 - y2_output_root_mean_squared_error: 2.1732 - val_loss: 23.4378 - val_y1_output_loss: 5.2164 - val_y2_output_loss: 18.5545 - val_y1_output_root_mean_squared_error: 2.2822 - val_y2_output_root_mean_squared_error: 4.2696
# Epoch 48/500
# 614/614 [==============================] - 0s 169us/sample - loss: 8.3925 - y1_output_loss: 2.4829 - y2_output_loss: 5.8818 - y1_output_root_mean_squared_error: 1.5786 - y2_output_root_mean_squared_error: 2.4291 - val_loss: 10.3573 - val_y1_output_loss: 3.2508 - val_y2_output_loss: 7.1437 - val_y1_output_root_mean_squared_error: 1.7684 - val_y2_output_root_mean_squared_error: 2.6889
# Epoch 49/500
# 614/614 [==============================] - 0s 168us/sample - loss: 7.6657 - y1_output_loss: 2.1538 - y2_output_loss: 5.5560 - y1_output_root_mean_squared_error: 1.4692 - y2_output_root_mean_squared_error: 2.3467 - val_loss: 7.7570 - val_y1_output_loss: 2.3769 - val_y2_output_loss: 5.2859 - val_y1_output_root_mean_squared_error: 1.5282 - val_y2_output_root_mean_squared_error: 2.3284
# Epoch 50/500
# 614/614 [==============================] - 0s 150us/sample - loss: 8.5013 - y1_output_loss: 2.7345 - y2_output_loss: 5.9153 - y1_output_root_mean_squared_error: 1.6366 - y2_output_root_mean_squared_error: 2.4131 - val_loss: 25.9552 - val_y1_output_loss: 9.4154 - val_y2_output_loss: 15.8856 - val_y1_output_root_mean_squared_error: 3.0904 - val_y2_output_root_mean_squared_error: 4.0503
# Epoch 51/500
# 614/614 [==============================] - 0s 162us/sample - loss: 9.3600 - y1_output_loss: 3.1205 - y2_output_loss: 6.1611 - y1_output_root_mean_squared_error: 1.7741 - y2_output_root_mean_squared_error: 2.4925 - val_loss: 5.5151 - val_y1_output_loss: 2.2715 - val_y2_output_loss: 3.4048 - val_y1_output_root_mean_squared_error: 1.4734 - val_y2_output_root_mean_squared_error: 1.8287
# Epoch 52/500
# 614/614 [==============================] - 0s 159us/sample - loss: 5.3418 - y1_output_loss: 1.7319 - y2_output_loss: 3.5969 - y1_output_root_mean_squared_error: 1.3143 - y2_output_root_mean_squared_error: 1.9012 - val_loss: 5.3197 - val_y1_output_loss: 2.1041 - val_y2_output_loss: 3.3340 - val_y1_output_root_mean_squared_error: 1.4351 - val_y2_output_root_mean_squared_error: 1.8056
# Epoch 53/500
# 614/614 [==============================] - 0s 164us/sample - loss: 7.9813 - y1_output_loss: 2.4316 - y2_output_loss: 5.4858 - y1_output_root_mean_squared_error: 1.5650 - y2_output_root_mean_squared_error: 2.3521 - val_loss: 5.5344 - val_y1_output_loss: 2.0235 - val_y2_output_loss: 3.5926 - val_y1_output_root_mean_squared_error: 1.4145 - val_y2_output_root_mean_squared_error: 1.8798
# Epoch 54/500
# 614/614 [==============================] - 0s 166us/sample - loss: 6.9128 - y1_output_loss: 1.9898 - y2_output_loss: 4.9273 - y1_output_root_mean_squared_error: 1.4062 - y2_output_root_mean_squared_error: 2.2216 - val_loss: 4.9175 - val_y1_output_loss: 1.7488 - val_y2_output_loss: 3.3609 - val_y1_output_root_mean_squared_error: 1.2981 - val_y2_output_root_mean_squared_error: 1.7979
# Epoch 55/500
# 614/614 [==============================] - 0s 158us/sample - loss: 5.9152 - y1_output_loss: 1.7629 - y2_output_loss: 4.1548 - y1_output_root_mean_squared_error: 1.3199 - y2_output_root_mean_squared_error: 2.0428 - val_loss: 4.7934 - val_y1_output_loss: 1.6630 - val_y2_output_loss: 3.2230 - val_y1_output_root_mean_squared_error: 1.2572 - val_y2_output_root_mean_squared_error: 1.7924
# Epoch 56/500
# 614/614 [==============================] - 0s 161us/sample - loss: 5.9477 - y1_output_loss: 1.8245 - y2_output_loss: 4.1336 - y1_output_root_mean_squared_error: 1.3496 - y2_output_root_mean_squared_error: 2.0314 - val_loss: 4.8483 - val_y1_output_loss: 1.5773 - val_y2_output_loss: 3.3443 - val_y1_output_root_mean_squared_error: 1.2500 - val_y2_output_root_mean_squared_error: 1.8127
# Epoch 57/500
# 614/614 [==============================] - 0s 166us/sample - loss: 5.5359 - y1_output_loss: 1.5294 - y2_output_loss: 3.9763 - y1_output_root_mean_squared_error: 1.2393 - y2_output_root_mean_squared_error: 2.0000 - val_loss: 4.5358 - val_y1_output_loss: 1.7129 - val_y2_output_loss: 2.9392 - val_y1_output_root_mean_squared_error: 1.2906 - val_y2_output_root_mean_squared_error: 1.6942
# Epoch 58/500
# 614/614 [==============================] - 0s 173us/sample - loss: 5.2623 - y1_output_loss: 1.5311 - y2_output_loss: 3.6843 - y1_output_root_mean_squared_error: 1.2429 - y2_output_root_mean_squared_error: 1.9281 - val_loss: 3.8237 - val_y1_output_loss: 1.3138 - val_y2_output_loss: 2.5655 - val_y1_output_root_mean_squared_error: 1.1272 - val_y2_output_root_mean_squared_error: 1.5978
# Epoch 59/500
# 614/614 [==============================] - 0s 180us/sample - loss: 4.8459 - y1_output_loss: 1.5596 - y2_output_loss: 3.2755 - y1_output_root_mean_squared_error: 1.2424 - y2_output_root_mean_squared_error: 1.8173 - val_loss: 5.3836 - val_y1_output_loss: 1.9205 - val_y2_output_loss: 3.4988 - val_y1_output_root_mean_squared_error: 1.3926 - val_y2_output_root_mean_squared_error: 1.8558
# Epoch 60/500
# 614/614 [==============================] - 0s 154us/sample - loss: 7.2501 - y1_output_loss: 2.1207 - y2_output_loss: 5.1154 - y1_output_root_mean_squared_error: 1.4617 - y2_output_root_mean_squared_error: 2.2613 - val_loss: 7.0135 - val_y1_output_loss: 1.9362 - val_y2_output_loss: 4.9497 - val_y1_output_root_mean_squared_error: 1.3856 - val_y2_output_root_mean_squared_error: 2.2569
# Epoch 61/500
# 614/614 [==============================] - 0s 162us/sample - loss: 8.5966 - y1_output_loss: 2.5818 - y2_output_loss: 5.9502 - y1_output_root_mean_squared_error: 1.6137 - y2_output_root_mean_squared_error: 2.4480 - val_loss: 4.4554 - val_y1_output_loss: 1.3266 - val_y2_output_loss: 3.1181 - val_y1_output_root_mean_squared_error: 1.1276 - val_y2_output_root_mean_squared_error: 1.7844
# Epoch 62/500
# 614/614 [==============================] - 0s 179us/sample - loss: 4.4947 - y1_output_loss: 1.1875 - y2_output_loss: 3.3186 - y1_output_root_mean_squared_error: 1.0889 - y2_output_root_mean_squared_error: 1.8191 - val_loss: 6.1059 - val_y1_output_loss: 1.4529 - val_y2_output_loss: 4.6767 - val_y1_output_root_mean_squared_error: 1.1623 - val_y2_output_root_mean_squared_error: 2.1806
# Epoch 63/500
# 614/614 [==============================] - 0s 161us/sample - loss: 6.2468 - y1_output_loss: 1.6841 - y2_output_loss: 4.5562 - y1_output_root_mean_squared_error: 1.2957 - y2_output_root_mean_squared_error: 2.1373 - val_loss: 6.9511 - val_y1_output_loss: 1.4037 - val_y2_output_loss: 5.7083 - val_y1_output_root_mean_squared_error: 1.1622 - val_y2_output_root_mean_squared_error: 2.3665
# Epoch 64/500
# 614/614 [==============================] - 0s 167us/sample - loss: 6.1131 - y1_output_loss: 1.5563 - y2_output_loss: 4.5973 - y1_output_root_mean_squared_error: 1.2445 - y2_output_root_mean_squared_error: 2.1364 - val_loss: 7.3127 - val_y1_output_loss: 2.3814 - val_y2_output_loss: 4.8138 - val_y1_output_root_mean_squared_error: 1.5387 - val_y2_output_root_mean_squared_error: 2.2237
# Epoch 65/500
# 614/614 [==============================] - 0s 169us/sample - loss: 3.6773 - y1_output_loss: 1.0193 - y2_output_loss: 2.6649 - y1_output_root_mean_squared_error: 1.0007 - y2_output_root_mean_squared_error: 1.6358 - val_loss: 5.6905 - val_y1_output_loss: 1.7199 - val_y2_output_loss: 4.0517 - val_y1_output_root_mean_squared_error: 1.3163 - val_y2_output_root_mean_squared_error: 1.9894
# Epoch 66/500
# 614/614 [==============================] - 0s 153us/sample - loss: 5.5005 - y1_output_loss: 1.4747 - y2_output_loss: 3.9988 - y1_output_root_mean_squared_error: 1.2188 - y2_output_root_mean_squared_error: 2.0038 - val_loss: 3.7396 - val_y1_output_loss: 0.9899 - val_y2_output_loss: 2.8352 - val_y1_output_root_mean_squared_error: 0.9904 - val_y2_output_root_mean_squared_error: 1.6609
# Epoch 67/500
# 614/614 [==============================] - 0s 167us/sample - loss: 4.1688 - y1_output_loss: 1.1480 - y2_output_loss: 3.0135 - y1_output_root_mean_squared_error: 1.0672 - y2_output_root_mean_squared_error: 1.7407 - val_loss: 3.7080 - val_y1_output_loss: 1.2822 - val_y2_output_loss: 2.5455 - val_y1_output_root_mean_squared_error: 1.1192 - val_y2_output_root_mean_squared_error: 1.5670
# Epoch 68/500
# 614/614 [==============================] - 0s 159us/sample - loss: 4.7608 - y1_output_loss: 1.2421 - y2_output_loss: 3.5114 - y1_output_root_mean_squared_error: 1.1155 - y2_output_root_mean_squared_error: 1.8752 - val_loss: 3.1235 - val_y1_output_loss: 0.9114 - val_y2_output_loss: 2.1963 - val_y1_output_root_mean_squared_error: 0.9376 - val_y2_output_root_mean_squared_error: 1.4981
# Epoch 69/500
# 614/614 [==============================] - 0s 157us/sample - loss: 4.0712 - y1_output_loss: 1.0083 - y2_output_loss: 3.0310 - y1_output_root_mean_squared_error: 1.0078 - y2_output_root_mean_squared_error: 1.7480 - val_loss: 3.4443 - val_y1_output_loss: 1.0362 - val_y2_output_loss: 2.5029 - val_y1_output_root_mean_squared_error: 1.0009 - val_y2_output_root_mean_squared_error: 1.5628
# Epoch 70/500
# 614/614 [==============================] - 0s 162us/sample - loss: 3.7869 - y1_output_loss: 0.9596 - y2_output_loss: 2.7982 - y1_output_root_mean_squared_error: 0.9835 - y2_output_root_mean_squared_error: 1.6792 - val_loss: 2.7350 - val_y1_output_loss: 0.7637 - val_y2_output_loss: 2.0147 - val_y1_output_root_mean_squared_error: 0.8613 - val_y2_output_root_mean_squared_error: 1.4118
# Epoch 71/500
# 614/614 [==============================] - 0s 152us/sample - loss: 4.2801 - y1_output_loss: 1.0343 - y2_output_loss: 3.2149 - y1_output_root_mean_squared_error: 1.0211 - y2_output_root_mean_squared_error: 1.7993 - val_loss: 3.5675 - val_y1_output_loss: 0.9623 - val_y2_output_loss: 2.5564 - val_y1_output_root_mean_squared_error: 0.9674 - val_y2_output_root_mean_squared_error: 1.6222
# Epoch 72/500
# 614/614 [==============================] - 0s 152us/sample - loss: 3.3481 - y1_output_loss: 0.8400 - y2_output_loss: 2.4804 - y1_output_root_mean_squared_error: 0.9198 - y2_output_root_mean_squared_error: 1.5818 - val_loss: 2.4011 - val_y1_output_loss: 0.6077 - val_y2_output_loss: 1.8321 - val_y1_output_root_mean_squared_error: 0.7695 - val_y2_output_root_mean_squared_error: 1.3450
# Epoch 73/500
# 614/614 [==============================] - 0s 165us/sample - loss: 4.9094 - y1_output_loss: 1.4461 - y2_output_loss: 3.5071 - y1_output_root_mean_squared_error: 1.2052 - y2_output_root_mean_squared_error: 1.8593 - val_loss: 10.5199 - val_y1_output_loss: 1.9009 - val_y2_output_loss: 8.8695 - val_y1_output_root_mean_squared_error: 1.3882 - val_y2_output_root_mean_squared_error: 2.9314
# Epoch 74/500
# 614/614 [==============================] - 0s 160us/sample - loss: 3.7580 - y1_output_loss: 0.8435 - y2_output_loss: 2.8949 - y1_output_root_mean_squared_error: 0.9217 - y2_output_root_mean_squared_error: 1.7054 - val_loss: 3.7102 - val_y1_output_loss: 0.8407 - val_y2_output_loss: 2.8147 - val_y1_output_root_mean_squared_error: 0.9018 - val_y2_output_root_mean_squared_error: 1.7020
# Epoch 75/500
# 614/614 [==============================] - 0s 160us/sample - loss: 4.9398 - y1_output_loss: 1.3811 - y2_output_loss: 3.6550 - y1_output_root_mean_squared_error: 1.1465 - y2_output_root_mean_squared_error: 1.9040 - val_loss: 31.5767 - val_y1_output_loss: 11.5561 - val_y2_output_loss: 19.9312 - val_y1_output_root_mean_squared_error: 3.4366 - val_y2_output_root_mean_squared_error: 4.4460
# Epoch 76/500
# 614/614 [==============================] - 0s 161us/sample - loss: 5.1714 - y1_output_loss: 1.5685 - y2_output_loss: 3.6340 - y1_output_root_mean_squared_error: 1.2572 - y2_output_root_mean_squared_error: 1.8949 - val_loss: 6.7484 - val_y1_output_loss: 1.3953 - val_y2_output_loss: 5.4565 - val_y1_output_root_mean_squared_error: 1.1914 - val_y2_output_root_mean_squared_error: 2.3084
# Epoch 77/500
# 614/614 [==============================] - 0s 153us/sample - loss: 5.5455 - y1_output_loss: 1.3265 - y2_output_loss: 4.1740 - y1_output_root_mean_squared_error: 1.1569 - y2_output_root_mean_squared_error: 2.0511 - val_loss: 4.7914 - val_y1_output_loss: 1.3886 - val_y2_output_loss: 3.4582 - val_y1_output_root_mean_squared_error: 1.1957 - val_y2_output_root_mean_squared_error: 1.8335
# Epoch 78/500
# 614/614 [==============================] - 0s 154us/sample - loss: 3.0655 - y1_output_loss: 0.7277 - y2_output_loss: 2.3588 - y1_output_root_mean_squared_error: 0.8519 - y2_output_root_mean_squared_error: 1.5296 - val_loss: 5.9806 - val_y1_output_loss: 1.2179 - val_y2_output_loss: 4.7247 - val_y1_output_root_mean_squared_error: 1.0738 - val_y2_output_root_mean_squared_error: 2.1972
# Epoch 79/500
# 614/614 [==============================] - 0s 159us/sample - loss: 5.3577 - y1_output_loss: 1.4533 - y2_output_loss: 3.8622 - y1_output_root_mean_squared_error: 1.2103 - y2_output_root_mean_squared_error: 1.9730 - val_loss: 2.7192 - val_y1_output_loss: 0.6998 - val_y2_output_loss: 2.0952 - val_y1_output_root_mean_squared_error: 0.8261 - val_y2_output_root_mean_squared_error: 1.4272
# Epoch 80/500
# 614/614 [==============================] - 0s 161us/sample - loss: 3.4959 - y1_output_loss: 0.7797 - y2_output_loss: 2.7188 - y1_output_root_mean_squared_error: 0.8812 - y2_output_root_mean_squared_error: 1.6490 - val_loss: 3.9281 - val_y1_output_loss: 0.8681 - val_y2_output_loss: 2.9711 - val_y1_output_root_mean_squared_error: 0.9224 - val_y2_output_root_mean_squared_error: 1.7542
# Epoch 81/500
# 614/614 [==============================] - 0s 188us/sample - loss: 3.7841 - y1_output_loss: 0.8205 - y2_output_loss: 2.9637 - y1_output_root_mean_squared_error: 0.9076 - y2_output_root_mean_squared_error: 1.7206 - val_loss: 3.5964 - val_y1_output_loss: 1.2813 - val_y2_output_loss: 2.2167 - val_y1_output_root_mean_squared_error: 1.1425 - val_y2_output_root_mean_squared_error: 1.5136
# Epoch 82/500
# 614/614 [==============================] - 0s 156us/sample - loss: 3.2725 - y1_output_loss: 0.8036 - y2_output_loss: 2.4494 - y1_output_root_mean_squared_error: 0.8957 - y2_output_root_mean_squared_error: 1.5717 - val_loss: 3.0419 - val_y1_output_loss: 0.6923 - val_y2_output_loss: 2.4276 - val_y1_output_root_mean_squared_error: 0.8299 - val_y2_output_root_mean_squared_error: 1.5340
# Epoch 83/500
# 614/614 [==============================] - 0s 156us/sample - loss: 4.7635 - y1_output_loss: 1.0849 - y2_output_loss: 3.7144 - y1_output_root_mean_squared_error: 1.0364 - y2_output_root_mean_squared_error: 1.9208 - val_loss: 10.6459 - val_y1_output_loss: 2.9889 - val_y2_output_loss: 7.4199 - val_y1_output_root_mean_squared_error: 1.7281 - val_y2_output_root_mean_squared_error: 2.7676
# Epoch 84/500
# 614/614 [==============================] - 0s 158us/sample - loss: 4.4180 - y1_output_loss: 1.2587 - y2_output_loss: 3.1463 - y1_output_root_mean_squared_error: 1.1239 - y2_output_root_mean_squared_error: 1.7762 - val_loss: 3.1764 - val_y1_output_loss: 0.6121 - val_y2_output_loss: 2.5095 - val_y1_output_root_mean_squared_error: 0.7728 - val_y2_output_root_mean_squared_error: 1.6060
# Epoch 85/500
# 614/614 [==============================] - 0s 159us/sample - loss: 3.9682 - y1_output_loss: 1.0500 - y2_output_loss: 2.8900 - y1_output_root_mean_squared_error: 1.0289 - y2_output_root_mean_squared_error: 1.7057 - val_loss: 2.7405 - val_y1_output_loss: 0.8188 - val_y2_output_loss: 1.9054 - val_y1_output_root_mean_squared_error: 0.9127 - val_y2_output_root_mean_squared_error: 1.3811
# Epoch 86/500
# 614/614 [==============================] - 0s 161us/sample - loss: 2.8428 - y1_output_loss: 0.6999 - y2_output_loss: 2.1380 - y1_output_root_mean_squared_error: 0.8380 - y2_output_root_mean_squared_error: 1.4631 - val_loss: 7.4522 - val_y1_output_loss: 1.4790 - val_y2_output_loss: 6.1052 - val_y1_output_root_mean_squared_error: 1.2336 - val_y2_output_root_mean_squared_error: 2.4353
# Epoch 87/500
# 614/614 [==============================] - 0s 159us/sample - loss: 2.9365 - y1_output_loss: 0.6499 - y2_output_loss: 2.2619 - y1_output_root_mean_squared_error: 0.8098 - y2_output_root_mean_squared_error: 1.5102 - val_loss: 2.7046 - val_y1_output_loss: 0.6619 - val_y2_output_loss: 2.0960 - val_y1_output_root_mean_squared_error: 0.8257 - val_y2_output_root_mean_squared_error: 1.4223
# Epoch 88/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.3975 - y1_output_loss: 0.8562 - y2_output_loss: 2.5241 - y1_output_root_mean_squared_error: 0.9296 - y2_output_root_mean_squared_error: 1.5916 - val_loss: 3.9760 - val_y1_output_loss: 0.6085 - val_y2_output_loss: 3.4938 - val_y1_output_root_mean_squared_error: 0.7904 - val_y2_output_root_mean_squared_error: 1.8306
# Epoch 89/500
# 614/614 [==============================] - 0s 155us/sample - loss: 8.2706 - y1_output_loss: 2.8253 - y2_output_loss: 5.4730 - y1_output_root_mean_squared_error: 1.6795 - y2_output_root_mean_squared_error: 2.3345 - val_loss: 4.4050 - val_y1_output_loss: 1.4705 - val_y2_output_loss: 2.8350 - val_y1_output_root_mean_squared_error: 1.2308 - val_y2_output_root_mean_squared_error: 1.7000
# Epoch 90/500
# 614/614 [==============================] - 0s 166us/sample - loss: 3.2918 - y1_output_loss: 0.7884 - y2_output_loss: 2.5515 - y1_output_root_mean_squared_error: 0.8750 - y2_output_root_mean_squared_error: 1.5894 - val_loss: 11.3647 - val_y1_output_loss: 2.7521 - val_y2_output_loss: 8.8446 - val_y1_output_root_mean_squared_error: 1.6739 - val_y2_output_root_mean_squared_error: 2.9262
# Epoch 91/500
# 614/614 [==============================] - 0s 158us/sample - loss: 3.4261 - y1_output_loss: 0.8553 - y2_output_loss: 2.5468 - y1_output_root_mean_squared_error: 0.9290 - y2_output_root_mean_squared_error: 1.6009 - val_loss: 2.2606 - val_y1_output_loss: 0.5813 - val_y2_output_loss: 1.6759 - val_y1_output_root_mean_squared_error: 0.7683 - val_y2_output_root_mean_squared_error: 1.2924
# Epoch 92/500
# 614/614 [==============================] - 0s 163us/sample - loss: 4.2191 - y1_output_loss: 1.0852 - y2_output_loss: 3.1007 - y1_output_root_mean_squared_error: 1.0441 - y2_output_root_mean_squared_error: 1.7689 - val_loss: 2.0731 - val_y1_output_loss: 0.4666 - val_y2_output_loss: 1.5893 - val_y1_output_root_mean_squared_error: 0.6748 - val_y2_output_root_mean_squared_error: 1.2719
# Epoch 93/500
# 614/614 [==============================] - 0s 149us/sample - loss: 5.4531 - y1_output_loss: 1.4343 - y2_output_loss: 3.9970 - y1_output_root_mean_squared_error: 1.2031 - y2_output_root_mean_squared_error: 2.0014 - val_loss: 3.8238 - val_y1_output_loss: 0.7035 - val_y2_output_loss: 3.0044 - val_y1_output_root_mean_squared_error: 0.8453 - val_y2_output_root_mean_squared_error: 1.7633
# Epoch 94/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.6308 - y1_output_loss: 0.6024 - y2_output_loss: 2.0565 - y1_output_root_mean_squared_error: 0.7782 - y2_output_root_mean_squared_error: 1.4231 - val_loss: 12.7593 - val_y1_output_loss: 2.6952 - val_y2_output_loss: 10.1113 - val_y1_output_root_mean_squared_error: 1.6688 - val_y2_output_root_mean_squared_error: 3.1582
# Epoch 95/500
# 614/614 [==============================] - 0s 157us/sample - loss: 2.4808 - y1_output_loss: 0.5808 - y2_output_loss: 1.8943 - y1_output_root_mean_squared_error: 0.7647 - y2_output_root_mean_squared_error: 1.3770 - val_loss: 3.1336 - val_y1_output_loss: 0.4032 - val_y2_output_loss: 2.6590 - val_y1_output_root_mean_squared_error: 0.6270 - val_y2_output_root_mean_squared_error: 1.6554
# Epoch 96/500
# 614/614 [==============================] - 0s 156us/sample - loss: 3.3289 - y1_output_loss: 0.6334 - y2_output_loss: 2.6780 - y1_output_root_mean_squared_error: 0.7980 - y2_output_root_mean_squared_error: 1.6408 - val_loss: 2.9942 - val_y1_output_loss: 0.7734 - val_y2_output_loss: 2.2136 - val_y1_output_root_mean_squared_error: 0.8840 - val_y2_output_root_mean_squared_error: 1.4875
# Epoch 97/500
# 614/614 [==============================] - 0s 159us/sample - loss: 3.1473 - y1_output_loss: 0.7816 - y2_output_loss: 2.3588 - y1_output_root_mean_squared_error: 0.8787 - y2_output_root_mean_squared_error: 1.5411 - val_loss: 2.5429 - val_y1_output_loss: 0.6814 - val_y2_output_loss: 1.8324 - val_y1_output_root_mean_squared_error: 0.8287 - val_y2_output_root_mean_squared_error: 1.3624
# Epoch 98/500
# 614/614 [==============================] - 0s 163us/sample - loss: 3.7124 - y1_output_loss: 0.8869 - y2_output_loss: 2.8037 - y1_output_root_mean_squared_error: 0.9459 - y2_output_root_mean_squared_error: 1.6786 - val_loss: 1.8933 - val_y1_output_loss: 0.4305 - val_y2_output_loss: 1.4497 - val_y1_output_root_mean_squared_error: 0.6652 - val_y2_output_root_mean_squared_error: 1.2045
# Epoch 99/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.8964 - y1_output_loss: 0.9488 - y2_output_loss: 2.9714 - y1_output_root_mean_squared_error: 0.9622 - y2_output_root_mean_squared_error: 1.7235 - val_loss: 17.7542 - val_y1_output_loss: 6.6862 - val_y2_output_loss: 10.8242 - val_y1_output_root_mean_squared_error: 2.6295 - val_y2_output_root_mean_squared_error: 3.2924
# Epoch 100/500
# 614/614 [==============================] - 0s 149us/sample - loss: 5.1339 - y1_output_loss: 1.6060 - y2_output_loss: 3.4938 - y1_output_root_mean_squared_error: 1.2730 - y2_output_root_mean_squared_error: 1.8744 - val_loss: 2.7129 - val_y1_output_loss: 0.8024 - val_y2_output_loss: 1.8435 - val_y1_output_root_mean_squared_error: 0.9081 - val_y2_output_root_mean_squared_error: 1.3741
# Epoch 101/500
# 614/614 [==============================] - 0s 161us/sample - loss: 2.5347 - y1_output_loss: 0.6424 - y2_output_loss: 1.8761 - y1_output_root_mean_squared_error: 0.8047 - y2_output_root_mean_squared_error: 1.3738 - val_loss: 2.6150 - val_y1_output_loss: 0.6083 - val_y2_output_loss: 2.0446 - val_y1_output_root_mean_squared_error: 0.7912 - val_y2_output_root_mean_squared_error: 1.4103
# Epoch 102/500
# 614/614 [==============================] - 0s 156us/sample - loss: 2.7533 - y1_output_loss: 0.6442 - y2_output_loss: 2.0903 - y1_output_root_mean_squared_error: 0.8044 - y2_output_root_mean_squared_error: 1.4513 - val_loss: 2.0524 - val_y1_output_loss: 0.4111 - val_y2_output_loss: 1.6666 - val_y1_output_root_mean_squared_error: 0.6482 - val_y2_output_root_mean_squared_error: 1.2776
# Epoch 103/500
# 614/614 [==============================] - 0s 157us/sample - loss: 3.4663 - y1_output_loss: 0.7543 - y2_output_loss: 2.6954 - y1_output_root_mean_squared_error: 0.8699 - y2_output_root_mean_squared_error: 1.6461 - val_loss: 1.9000 - val_y1_output_loss: 0.3906 - val_y2_output_loss: 1.4966 - val_y1_output_root_mean_squared_error: 0.6273 - val_y2_output_root_mean_squared_error: 1.2274
# Epoch 104/500
# 614/614 [==============================] - 0s 156us/sample - loss: 2.3332 - y1_output_loss: 0.4720 - y2_output_loss: 1.8952 - y1_output_root_mean_squared_error: 0.6778 - y2_output_root_mean_squared_error: 1.3689 - val_loss: 4.1281 - val_y1_output_loss: 0.6235 - val_y2_output_loss: 3.3947 - val_y1_output_root_mean_squared_error: 0.7841 - val_y2_output_root_mean_squared_error: 1.8744
# Epoch 105/500
# 614/614 [==============================] - 0s 149us/sample - loss: 4.5664 - y1_output_loss: 1.3010 - y2_output_loss: 3.2978 - y1_output_root_mean_squared_error: 1.1436 - y2_output_root_mean_squared_error: 1.8052 - val_loss: 5.1513 - val_y1_output_loss: 0.8037 - val_y2_output_loss: 4.4167 - val_y1_output_root_mean_squared_error: 0.9091 - val_y2_output_root_mean_squared_error: 2.0796
# Epoch 106/500
# 614/614 [==============================] - 0s 151us/sample - loss: 2.5971 - y1_output_loss: 0.6597 - y2_output_loss: 1.9661 - y1_output_root_mean_squared_error: 0.8084 - y2_output_root_mean_squared_error: 1.3941 - val_loss: 3.2711 - val_y1_output_loss: 0.7840 - val_y2_output_loss: 2.4262 - val_y1_output_root_mean_squared_error: 0.8916 - val_y2_output_root_mean_squared_error: 1.5736
# Epoch 107/500
# 614/614 [==============================] - 0s 161us/sample - loss: 2.4762 - y1_output_loss: 0.5385 - y2_output_loss: 1.9290 - y1_output_root_mean_squared_error: 0.7364 - y2_output_root_mean_squared_error: 1.3907 - val_loss: 2.2317 - val_y1_output_loss: 0.3517 - val_y2_output_loss: 1.8241 - val_y1_output_root_mean_squared_error: 0.5930 - val_y2_output_root_mean_squared_error: 1.3712
# Epoch 108/500
# 614/614 [==============================] - 0s 156us/sample - loss: 2.0183 - y1_output_loss: 0.5414 - y2_output_loss: 1.4747 - y1_output_root_mean_squared_error: 0.7387 - y2_output_root_mean_squared_error: 1.2135 - val_loss: 2.8921 - val_y1_output_loss: 0.5158 - val_y2_output_loss: 2.4450 - val_y1_output_root_mean_squared_error: 0.7288 - val_y2_output_root_mean_squared_error: 1.5365
# Epoch 109/500
# 614/614 [==============================] - 0s 174us/sample - loss: 2.8852 - y1_output_loss: 0.7619 - y2_output_loss: 2.3272 - y1_output_root_mean_squared_error: 0.8167 - y2_output_root_mean_squared_error: 1.4894 - val_loss: 97.5929 - val_y1_output_loss: 32.5547 - val_y2_output_loss: 62.6262 - val_y1_output_root_mean_squared_error: 5.7784 - val_y2_output_root_mean_squared_error: 8.0126
# Epoch 110/500
# 614/614 [==============================] - 0s 159us/sample - loss: 5.9744 - y1_output_loss: 1.7540 - y2_output_loss: 4.1880 - y1_output_root_mean_squared_error: 1.3290 - y2_output_root_mean_squared_error: 2.0514 - val_loss: 3.7204 - val_y1_output_loss: 0.8602 - val_y2_output_loss: 2.9192 - val_y1_output_root_mean_squared_error: 0.9424 - val_y2_output_root_mean_squared_error: 1.6830
# Epoch 111/500
# 614/614 [==============================] - 0s 153us/sample - loss: 2.4495 - y1_output_loss: 0.5818 - y2_output_loss: 1.8983 - y1_output_root_mean_squared_error: 0.7651 - y2_output_root_mean_squared_error: 1.3653 - val_loss: 2.9357 - val_y1_output_loss: 0.3844 - val_y2_output_loss: 2.6345 - val_y1_output_root_mean_squared_error: 0.6172 - val_y2_output_root_mean_squared_error: 1.5984
# Epoch 112/500
# 614/614 [==============================] - 0s 162us/sample - loss: 2.2528 - y1_output_loss: 0.5283 - y2_output_loss: 1.7306 - y1_output_root_mean_squared_error: 0.7281 - y2_output_root_mean_squared_error: 1.3125 - val_loss: 4.6900 - val_y1_output_loss: 0.8058 - val_y2_output_loss: 3.9879 - val_y1_output_root_mean_squared_error: 0.9076 - val_y2_output_root_mean_squared_error: 1.9663
# Epoch 113/500
# 614/614 [==============================] - 0s 158us/sample - loss: 2.4314 - y1_output_loss: 0.5025 - y2_output_loss: 1.9121 - y1_output_root_mean_squared_error: 0.7096 - y2_output_root_mean_squared_error: 1.3885 - val_loss: 2.1799 - val_y1_output_loss: 0.6067 - val_y2_output_loss: 1.5556 - val_y1_output_root_mean_squared_error: 0.7883 - val_y2_output_root_mean_squared_error: 1.2484
# Epoch 114/500
# 614/614 [==============================] - 0s 158us/sample - loss: 2.2592 - y1_output_loss: 0.4777 - y2_output_loss: 1.7726 - y1_output_root_mean_squared_error: 0.6919 - y2_output_root_mean_squared_error: 1.3343 - val_loss: 1.8401 - val_y1_output_loss: 0.4024 - val_y2_output_loss: 1.4134 - val_y1_output_root_mean_squared_error: 0.6361 - val_y2_output_root_mean_squared_error: 1.1981
# Epoch 115/500
# 614/614 [==============================] - 0s 163us/sample - loss: 1.9475 - y1_output_loss: 0.4033 - y2_output_loss: 1.5292 - y1_output_root_mean_squared_error: 0.6370 - y2_output_root_mean_squared_error: 1.2417 - val_loss: 2.2942 - val_y1_output_loss: 0.4522 - val_y2_output_loss: 1.8949 - val_y1_output_root_mean_squared_error: 0.6806 - val_y2_output_root_mean_squared_error: 1.3531
# Epoch 116/500
# 614/614 [==============================] - 0s 151us/sample - loss: 2.0121 - y1_output_loss: 0.4407 - y2_output_loss: 1.5743 - y1_output_root_mean_squared_error: 0.6658 - y2_output_root_mean_squared_error: 1.2525 - val_loss: 3.4104 - val_y1_output_loss: 0.6088 - val_y2_output_loss: 2.8745 - val_y1_output_root_mean_squared_error: 0.7864 - val_y2_output_root_mean_squared_error: 1.6709
# Epoch 117/500
# 614/614 [==============================] - 0s 150us/sample - loss: 4.1853 - y1_output_loss: 1.1106 - y2_output_loss: 3.0534 - y1_output_root_mean_squared_error: 1.0507 - y2_output_root_mean_squared_error: 1.7554 - val_loss: 2.1300 - val_y1_output_loss: 0.6149 - val_y2_output_loss: 1.5029 - val_y1_output_root_mean_squared_error: 0.7972 - val_y2_output_root_mean_squared_error: 1.2225
# Epoch 118/500
# 614/614 [==============================] - 0s 157us/sample - loss: 2.1371 - y1_output_loss: 0.5231 - y2_output_loss: 1.5984 - y1_output_root_mean_squared_error: 0.7254 - y2_output_root_mean_squared_error: 1.2692 - val_loss: 1.5892 - val_y1_output_loss: 0.3163 - val_y2_output_loss: 1.2734 - val_y1_output_root_mean_squared_error: 0.5601 - val_y2_output_root_mean_squared_error: 1.1293
# Epoch 119/500
# 614/614 [==============================] - 0s 156us/sample - loss: 2.2615 - y1_output_loss: 0.5146 - y2_output_loss: 1.7298 - y1_output_root_mean_squared_error: 0.7194 - y2_output_root_mean_squared_error: 1.3206 - val_loss: 3.4404 - val_y1_output_loss: 0.7434 - val_y2_output_loss: 2.7694 - val_y1_output_root_mean_squared_error: 0.8720 - val_y2_output_root_mean_squared_error: 1.6371
# Epoch 120/500
# 614/614 [==============================] - 0s 157us/sample - loss: 2.0667 - y1_output_loss: 0.3920 - y2_output_loss: 1.6874 - y1_output_root_mean_squared_error: 0.6250 - y2_output_root_mean_squared_error: 1.2947 - val_loss: 3.3514 - val_y1_output_loss: 0.5886 - val_y2_output_loss: 2.8342 - val_y1_output_root_mean_squared_error: 0.7767 - val_y2_output_root_mean_squared_error: 1.6578
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 162us/sample - loss: 0.3181 - y1_output_loss: 0.1140 - y2_output_loss: 0.2083 - y1_output_root_mean_squared_error: 0.3302 - y2_output_root_mean_squared_error: 0.4573 - val_loss: 0.8629 - val_y1_output_loss: 0.3307 - val_y2_output_loss: 0.5304 - val_y1_output_root_mean_squared_error: 0.5736 - val_y2_output_root_mean_squared_error: 0.7307
# Epoch 462/500
# 614/614 [==============================] - 0s 170us/sample - loss: 0.3983 - y1_output_loss: 0.1272 - y2_output_loss: 0.2688 - y1_output_root_mean_squared_error: 0.3573 - y2_output_root_mean_squared_error: 0.5202 - val_loss: 0.5167 - val_y1_output_loss: 0.1254 - val_y2_output_loss: 0.3855 - val_y1_output_root_mean_squared_error: 0.3592 - val_y2_output_root_mean_squared_error: 0.6226
# Epoch 463/500
# 614/614 [==============================] - 0s 175us/sample - loss: 0.3233 - y1_output_loss: 0.1052 - y2_output_loss: 0.2197 - y1_output_root_mean_squared_error: 0.3243 - y2_output_root_mean_squared_error: 0.4670 - val_loss: 0.9354 - val_y1_output_loss: 0.1539 - val_y2_output_loss: 0.7968 - val_y1_output_root_mean_squared_error: 0.3959 - val_y2_output_root_mean_squared_error: 0.8824
# Epoch 464/500
# 614/614 [==============================] - 0s 160us/sample - loss: 0.3288 - y1_output_loss: 0.1086 - y2_output_loss: 0.2180 - y1_output_root_mean_squared_error: 0.3308 - y2_output_root_mean_squared_error: 0.4683 - val_loss: 0.6436 - val_y1_output_loss: 0.1385 - val_y2_output_loss: 0.5094 - val_y1_output_root_mean_squared_error: 0.3753 - val_y2_output_root_mean_squared_error: 0.7091
# Epoch 465/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.3201 - y1_output_loss: 0.1120 - y2_output_loss: 0.2128 - y1_output_root_mean_squared_error: 0.3317 - y2_output_root_mean_squared_error: 0.4583 - val_loss: 1.1499 - val_y1_output_loss: 0.1709 - val_y2_output_loss: 0.9451 - val_y1_output_root_mean_squared_error: 0.4179 - val_y2_output_root_mean_squared_error: 0.9875
# Epoch 466/500
# 614/614 [==============================] - 0s 162us/sample - loss: 0.3496 - y1_output_loss: 0.1161 - y2_output_loss: 0.2331 - y1_output_root_mean_squared_error: 0.3402 - y2_output_root_mean_squared_error: 0.4836 - val_loss: 0.8386 - val_y1_output_loss: 0.2253 - val_y2_output_loss: 0.6026 - val_y1_output_root_mean_squared_error: 0.4805 - val_y2_output_root_mean_squared_error: 0.7795
# Epoch 467/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.5698 - y1_output_loss: 0.1461 - y2_output_loss: 0.4217 - y1_output_root_mean_squared_error: 0.3824 - y2_output_root_mean_squared_error: 0.6509 - val_loss: 0.5453 - val_y1_output_loss: 0.1366 - val_y2_output_loss: 0.4168 - val_y1_output_root_mean_squared_error: 0.3699 - val_y2_output_root_mean_squared_error: 0.6391
# Epoch 468/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.3899 - y1_output_loss: 0.1344 - y2_output_loss: 0.2538 - y1_output_root_mean_squared_error: 0.3671 - y2_output_root_mean_squared_error: 0.5052 - val_loss: 0.5412 - val_y1_output_loss: 0.1588 - val_y2_output_loss: 0.3774 - val_y1_output_root_mean_squared_error: 0.4017 - val_y2_output_root_mean_squared_error: 0.6163
# Epoch 469/500
# 614/614 [==============================] - 0s 164us/sample - loss: 0.3239 - y1_output_loss: 0.1076 - y2_output_loss: 0.2154 - y1_output_root_mean_squared_error: 0.3285 - y2_output_root_mean_squared_error: 0.4647 - val_loss: 0.6571 - val_y1_output_loss: 0.1234 - val_y2_output_loss: 0.5192 - val_y1_output_root_mean_squared_error: 0.3545 - val_y2_output_root_mean_squared_error: 0.7290
# Epoch 470/500
# 614/614 [==============================] - 0s 154us/sample - loss: 0.5142 - y1_output_loss: 0.1918 - y2_output_loss: 0.3242 - y1_output_root_mean_squared_error: 0.4384 - y2_output_root_mean_squared_error: 0.5675 - val_loss: 0.9670 - val_y1_output_loss: 0.3623 - val_y2_output_loss: 0.5754 - val_y1_output_root_mean_squared_error: 0.6101 - val_y2_output_root_mean_squared_error: 0.7712
# Epoch 471/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.5830 - y1_output_loss: 0.1782 - y2_output_loss: 0.4007 - y1_output_root_mean_squared_error: 0.4241 - y2_output_root_mean_squared_error: 0.6349 - val_loss: 0.6879 - val_y1_output_loss: 0.1439 - val_y2_output_loss: 0.5658 - val_y1_output_root_mean_squared_error: 0.3800 - val_y2_output_root_mean_squared_error: 0.7372
# Epoch 472/500
# 614/614 [==============================] - 0s 160us/sample - loss: 0.3913 - y1_output_loss: 0.1254 - y2_output_loss: 0.2986 - y1_output_root_mean_squared_error: 0.3401 - y2_output_root_mean_squared_error: 0.5250 - val_loss: 4.1320 - val_y1_output_loss: 1.8651 - val_y2_output_loss: 2.2276 - val_y1_output_root_mean_squared_error: 1.3793 - val_y2_output_root_mean_squared_error: 1.4931
# Epoch 473/500
# 614/614 [==============================] - 0s 158us/sample - loss: 0.6499 - y1_output_loss: 0.1941 - y2_output_loss: 0.4504 - y1_output_root_mean_squared_error: 0.4426 - y2_output_root_mean_squared_error: 0.6738 - val_loss: 0.6041 - val_y1_output_loss: 0.1484 - val_y2_output_loss: 0.4659 - val_y1_output_root_mean_squared_error: 0.3882 - val_y2_output_root_mean_squared_error: 0.6734
# Epoch 474/500
# 614/614 [==============================] - 0s 159us/sample - loss: 2.3639 - y1_output_loss: 0.8024 - y2_output_loss: 1.5402 - y1_output_root_mean_squared_error: 0.8999 - y2_output_root_mean_squared_error: 1.2467 - val_loss: 0.5888 - val_y1_output_loss: 0.1491 - val_y2_output_loss: 0.4237 - val_y1_output_root_mean_squared_error: 0.3880 - val_y2_output_root_mean_squared_error: 0.6620
# Epoch 475/500
# 614/614 [==============================] - 0s 160us/sample - loss: 0.6969 - y1_output_loss: 0.1722 - y2_output_loss: 0.5188 - y1_output_root_mean_squared_error: 0.4165 - y2_output_root_mean_squared_error: 0.7235 - val_loss: 0.5187 - val_y1_output_loss: 0.1264 - val_y2_output_loss: 0.3858 - val_y1_output_root_mean_squared_error: 0.3594 - val_y2_output_root_mean_squared_error: 0.6242
# Epoch 476/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.4263 - y1_output_loss: 0.1361 - y2_output_loss: 0.2876 - y1_output_root_mean_squared_error: 0.3701 - y2_output_root_mean_squared_error: 0.5379 - val_loss: 0.6328 - val_y1_output_loss: 0.1545 - val_y2_output_loss: 0.4580 - val_y1_output_root_mean_squared_error: 0.4004 - val_y2_output_root_mean_squared_error: 0.6874
# Epoch 477/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.3233 - y1_output_loss: 0.1040 - y2_output_loss: 0.2176 - y1_output_root_mean_squared_error: 0.3238 - y2_output_root_mean_squared_error: 0.4674 - val_loss: 0.6037 - val_y1_output_loss: 0.1892 - val_y2_output_loss: 0.4085 - val_y1_output_root_mean_squared_error: 0.4365 - val_y2_output_root_mean_squared_error: 0.6428
# Epoch 478/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.4162 - y1_output_loss: 0.1188 - y2_output_loss: 0.2945 - y1_output_root_mean_squared_error: 0.3455 - y2_output_root_mean_squared_error: 0.5448 - val_loss: 0.5237 - val_y1_output_loss: 0.1247 - val_y2_output_loss: 0.3981 - val_y1_output_root_mean_squared_error: 0.3580 - val_y2_output_root_mean_squared_error: 0.6289
# Epoch 479/500
# 614/614 [==============================] - 0s 165us/sample - loss: 0.3052 - y1_output_loss: 0.1131 - y2_output_loss: 0.1895 - y1_output_root_mean_squared_error: 0.3379 - y2_output_root_mean_squared_error: 0.4370 - val_loss: 0.5040 - val_y1_output_loss: 0.1319 - val_y2_output_loss: 0.3669 - val_y1_output_root_mean_squared_error: 0.3651 - val_y2_output_root_mean_squared_error: 0.6088
# Epoch 480/500
# 614/614 [==============================] - 0s 168us/sample - loss: 0.2687 - y1_output_loss: 0.0976 - y2_output_loss: 0.1707 - y1_output_root_mean_squared_error: 0.3137 - y2_output_root_mean_squared_error: 0.4127 - val_loss: 0.7383 - val_y1_output_loss: 0.2138 - val_y2_output_loss: 0.5325 - val_y1_output_root_mean_squared_error: 0.4641 - val_y2_output_root_mean_squared_error: 0.7231
# Epoch 481/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.3372 - y1_output_loss: 0.1077 - y2_output_loss: 0.2299 - y1_output_root_mean_squared_error: 0.3262 - y2_output_root_mean_squared_error: 0.4804 - val_loss: 1.1543 - val_y1_output_loss: 0.5046 - val_y2_output_loss: 0.6362 - val_y1_output_root_mean_squared_error: 0.7165 - val_y2_output_root_mean_squared_error: 0.8006
# Epoch 482/500
# 614/614 [==============================] - 0s 160us/sample - loss: 0.3022 - y1_output_loss: 0.1206 - y2_output_loss: 0.1799 - y1_output_root_mean_squared_error: 0.3474 - y2_output_root_mean_squared_error: 0.4260 - val_loss: 0.6481 - val_y1_output_loss: 0.1461 - val_y2_output_loss: 0.4840 - val_y1_output_root_mean_squared_error: 0.3872 - val_y2_output_root_mean_squared_error: 0.7058
# Epoch 483/500
# 614/614 [==============================] - 0s 163us/sample - loss: 0.2839 - y1_output_loss: 0.1111 - y2_output_loss: 0.1826 - y1_output_root_mean_squared_error: 0.3216 - y2_output_root_mean_squared_error: 0.4248 - val_loss: 1.7789 - val_y1_output_loss: 0.6134 - val_y2_output_loss: 1.1144 - val_y1_output_root_mean_squared_error: 0.7964 - val_y2_output_root_mean_squared_error: 1.0698
# Epoch 484/500
# 614/614 [==============================] - 0s 160us/sample - loss: 0.3143 - y1_output_loss: 0.1092 - y2_output_loss: 0.2023 - y1_output_root_mean_squared_error: 0.3320 - y2_output_root_mean_squared_error: 0.4517 - val_loss: 0.5150 - val_y1_output_loss: 0.1215 - val_y2_output_loss: 0.3893 - val_y1_output_root_mean_squared_error: 0.3515 - val_y2_output_root_mean_squared_error: 0.6257
# Epoch 485/500
# 614/614 [==============================] - 0s 165us/sample - loss: 0.3043 - y1_output_loss: 0.0988 - y2_output_loss: 0.2055 - y1_output_root_mean_squared_error: 0.3116 - y2_output_root_mean_squared_error: 0.4552 - val_loss: 0.5485 - val_y1_output_loss: 0.1706 - val_y2_output_loss: 0.3772 - val_y1_output_root_mean_squared_error: 0.4177 - val_y2_output_root_mean_squared_error: 0.6116
# Epoch 486/500
# 614/614 [==============================] - 0s 160us/sample - loss: 0.2736 - y1_output_loss: 0.0976 - y2_output_loss: 0.1750 - y1_output_root_mean_squared_error: 0.3118 - y2_output_root_mean_squared_error: 0.4200 - val_loss: 0.5659 - val_y1_output_loss: 0.1587 - val_y2_output_loss: 0.4056 - val_y1_output_root_mean_squared_error: 0.3948 - val_y2_output_root_mean_squared_error: 0.6403
# Epoch 487/500
# 614/614 [==============================] - 0s 176us/sample - loss: 0.2727 - y1_output_loss: 0.0992 - y2_output_loss: 0.1712 - y1_output_root_mean_squared_error: 0.3161 - y2_output_root_mean_squared_error: 0.4157 - val_loss: 0.5573 - val_y1_output_loss: 0.1504 - val_y2_output_loss: 0.4107 - val_y1_output_root_mean_squared_error: 0.3896 - val_y2_output_root_mean_squared_error: 0.6367
# Epoch 488/500
# 614/614 [==============================] - 0s 164us/sample - loss: 0.3843 - y1_output_loss: 0.1134 - y2_output_loss: 0.2754 - y1_output_root_mean_squared_error: 0.3360 - y2_output_root_mean_squared_error: 0.5210 - val_loss: 1.4604 - val_y1_output_loss: 0.2329 - val_y2_output_loss: 1.1943 - val_y1_output_root_mean_squared_error: 0.4904 - val_y2_output_root_mean_squared_error: 1.1045
# Epoch 489/500
# 614/614 [==============================] - 0s 162us/sample - loss: 0.3575 - y1_output_loss: 0.1117 - y2_output_loss: 0.2451 - y1_output_root_mean_squared_error: 0.3355 - y2_output_root_mean_squared_error: 0.4949 - val_loss: 0.6784 - val_y1_output_loss: 0.1573 - val_y2_output_loss: 0.5033 - val_y1_output_root_mean_squared_error: 0.4031 - val_y2_output_root_mean_squared_error: 0.7183
# Epoch 490/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.3269 - y1_output_loss: 0.1103 - y2_output_loss: 0.2146 - y1_output_root_mean_squared_error: 0.3335 - y2_output_root_mean_squared_error: 0.4644 - val_loss: 0.5669 - val_y1_output_loss: 0.1528 - val_y2_output_loss: 0.4099 - val_y1_output_root_mean_squared_error: 0.3917 - val_y2_output_root_mean_squared_error: 0.6430
# Epoch 491/500
# 614/614 [==============================] - 0s 171us/sample - loss: 0.4429 - y1_output_loss: 0.1160 - y2_output_loss: 0.3237 - y1_output_root_mean_squared_error: 0.3419 - y2_output_root_mean_squared_error: 0.5710 - val_loss: 0.5528 - val_y1_output_loss: 0.1269 - val_y2_output_loss: 0.4340 - val_y1_output_root_mean_squared_error: 0.3541 - val_y2_output_root_mean_squared_error: 0.6538
# Epoch 492/500
# 614/614 [==============================] - 0s 159us/sample - loss: 0.3488 - y1_output_loss: 0.1106 - y2_output_loss: 0.2361 - y1_output_root_mean_squared_error: 0.3333 - y2_output_root_mean_squared_error: 0.4876 - val_loss: 0.7002 - val_y1_output_loss: 0.2411 - val_y2_output_loss: 0.4598 - val_y1_output_root_mean_squared_error: 0.4936 - val_y2_output_root_mean_squared_error: 0.6756
# Epoch 493/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.2504 - y1_output_loss: 0.0879 - y2_output_loss: 0.1692 - y1_output_root_mean_squared_error: 0.2979 - y2_output_root_mean_squared_error: 0.4021 - val_loss: 1.3915 - val_y1_output_loss: 0.2220 - val_y2_output_loss: 1.1951 - val_y1_output_root_mean_squared_error: 0.4733 - val_y2_output_root_mean_squared_error: 1.0805
# Epoch 494/500
# 614/614 [==============================] - 0s 166us/sample - loss: 0.3783 - y1_output_loss: 0.1366 - y2_output_loss: 0.2479 - y1_output_root_mean_squared_error: 0.3657 - y2_output_root_mean_squared_error: 0.4945 - val_loss: 2.6281 - val_y1_output_loss: 0.8075 - val_y2_output_loss: 1.8423 - val_y1_output_root_mean_squared_error: 0.9071 - val_y2_output_root_mean_squared_error: 1.3436
# Epoch 495/500
# 614/614 [==============================] - 0s 160us/sample - loss: 0.3820 - y1_output_loss: 0.1306 - y2_output_loss: 0.2508 - y1_output_root_mean_squared_error: 0.3626 - y2_output_root_mean_squared_error: 0.5005 - val_loss: 0.5498 - val_y1_output_loss: 0.1303 - val_y2_output_loss: 0.4247 - val_y1_output_root_mean_squared_error: 0.3623 - val_y2_output_root_mean_squared_error: 0.6469
# Epoch 496/500
# 614/614 [==============================] - 0s 167us/sample - loss: 0.3454 - y1_output_loss: 0.1253 - y2_output_loss: 0.2280 - y1_output_root_mean_squared_error: 0.3471 - y2_output_root_mean_squared_error: 0.4742 - val_loss: 4.5692 - val_y1_output_loss: 1.6339 - val_y2_output_loss: 2.7929 - val_y1_output_root_mean_squared_error: 1.3010 - val_y2_output_root_mean_squared_error: 1.6961
# Epoch 497/500
# 614/614 [==============================] - 0s 163us/sample - loss: 0.3373 - y1_output_loss: 0.1242 - y2_output_loss: 0.2106 - y1_output_root_mean_squared_error: 0.3538 - y2_output_root_mean_squared_error: 0.4606 - val_loss: 0.5826 - val_y1_output_loss: 0.1750 - val_y2_output_loss: 0.4032 - val_y1_output_root_mean_squared_error: 0.4222 - val_y2_output_root_mean_squared_error: 0.6358
# Epoch 498/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.3100 - y1_output_loss: 0.1134 - y2_output_loss: 0.1967 - y1_output_root_mean_squared_error: 0.3358 - y2_output_root_mean_squared_error: 0.4441 - val_loss: 0.7291 - val_y1_output_loss: 0.2254 - val_y2_output_loss: 0.5169 - val_y1_output_root_mean_squared_error: 0.4789 - val_y2_output_root_mean_squared_error: 0.7069
# Epoch 499/500
# 614/614 [==============================] - 0s 163us/sample - loss: 0.3132 - y1_output_loss: 0.1134 - y2_output_loss: 0.2010 - y1_output_root_mean_squared_error: 0.3347 - y2_output_root_mean_squared_error: 0.4485 - val_loss: 0.7032 - val_y1_output_loss: 0.1669 - val_y2_output_loss: 0.5541 - val_y1_output_root_mean_squared_error: 0.4046 - val_y2_output_root_mean_squared_error: 0.7345
# Epoch 500/500
# 614/614 [==============================] - 0s 160us/sample - loss: 0.4193 - y1_output_loss: 0.1309 - y2_output_loss: 0.2884 - y1_output_root_mean_squared_error: 0.3619 - y2_output_root_mean_squared_error: 0.5370 - val_loss: 0.6541 - val_y1_output_loss: 0.1193 - val_y2_output_loss: 0.5233 - val_y1_output_root_mean_squared_error: 0.3489 - val_y2_output_root_mean_squared_error: 0.7296

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 39us/sample - loss: 0.6541 - y1_output_loss: 0.1216 - y2_output_loss: 0.5284 - y1_output_root_mean_squared_error: 0.3489 - y2_output_root_mean_squared_error: 0.7296
# Loss = 0.6540702883299295, Y1_loss = 0.12161965668201447, Y1_mse = 0.34887418150901794, Y2_loss = 0.5284164547920227, Y2_mse = 0.7296280264854431

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
